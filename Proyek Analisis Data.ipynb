# %% [markdown]
# # Proyek Analisis Data: Bike Sharing Dataset
# - **Nama:** Michael Christian Pribadi Lukito
# - **Email:** mcmikechrist@gmail.com
# - **ID Dicoding:** lasciarmi

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pada musim apa jumlah penyewaan sepeda paling banyak dilakukan dalam beberapa bulan terakhir?
# - Bagaimana perbandingan rata-rata jam peminjaman sepeda yang dilakukan di hari libur dan bukan hari libur?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# Import from google drive

# %% [markdown]
# Load tabel day.csv

# %%
day_df = pd.read_csv('day.csv')
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# Load tabel hour

# %%
hour_df = pd.read_csv('hour.csv')
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# **Insight:**
# - Dari 5 data yang ditampilkan pada tabel diatas, disimpulkan bahwa peminjaman paling banyak dilakukan pada musim semi, pada hari kerja dan cuaca yang cerah dengan waktu paling banyak dipinjam selama 1 jam

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# Menilai tabel day_df

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# Mengecek missing value

# %%
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# Mengecek duplikasi data

# %%
print("Jumlah duplikasi: ", day_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# Mengecek apakah ada keanehan atau tidak dalam data

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %% [markdown]
# Menilai tabel hour_df

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %% [markdown]
# Mengecek missing value

# %%
hour_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# Mengecek duplikasi data

# %%
print("Jumlah duplikasi: ", hour_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# Mengecek apakah ada keanehan atau tidak dalam data

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# **Insight:**
# - Tidak ada missing value dari tabel diatas
# - Tidak ada duplikasi data
# - Tidak keanehan dalam data

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# **Insight:**
# - Karena tidak ada duplikasi data, tidak ada missing value, dan tidak ada data yang tidak akurat maka tidak perlu cleaning data

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore day_df

# %% [markdown]
# Mencari Keadaan yang menyebabkan peminjaman sepeda meningkat

# %%
day_df.describe(include="all")
# Out:
#            instant      dteday      season          yr        mnth  \
# count   731.000000         731  731.000000  731.000000  731.000000
# unique         NaN         731         NaN         NaN         NaN
# top            NaN  2011-01-01         NaN         NaN         NaN
# freq           NaN           1         NaN         NaN         NaN
# mean    366.000000         NaN    2.496580    0.500684    6.519836
# std     211.165812         NaN    1.110807    0.500342    3.451913
# min       1.000000         NaN    1.000000    0.000000    1.000000
# 25%     183.500000         NaN    2.000000    0.000000    4.000000
# 50%     366.000000         NaN    3.000000    1.000000    7.000000
# 75%     548.500000         NaN    3.000000    1.000000   10.000000
# max     731.000000         NaN    4.000000    1.000000   12.000000
#
#            holiday     weekday  workingday  weathersit        temp  \
# count   731.000000  731.000000  731.000000  731.000000  731.000000
# ...

# %% [markdown]
# Mencari tahu Season apa yang paling banyak dilakukan peminjaman sepeda

# %%
# mappings = {
#     1: "musim semi",
#     2: "musim panas",
#     3: "musim gugur",
#     4: "musim dingin"
# }

# jika ingin mengubah angka ke dalam bentuk teks
# day_df["season"] = day_df["season"].map(mappings)
day_df.groupby(by="season").cnt.max()
# Out:
# season
# 1    7836
# 2    8362
# 3    8714
# 4    8555
# Name: cnt, dtype: int64

# %% [markdown]
# ### Explore hour_df

# %% [markdown]
# Mencari pada jam berapa rata-rata dilakukan peminjaman sepeda pada hari libur dan bukan hari libur

# %%
hour_df.describe(include="all")
# Out:
#            instant      dteday        season            yr          mnth  \
# count   17379.0000       17379  17379.000000  17379.000000  17379.000000
# unique         NaN         731           NaN           NaN           NaN
# top            NaN  2011-01-01           NaN           NaN           NaN
# freq           NaN          24           NaN           NaN           NaN
# mean     8690.0000         NaN      2.501640      0.502561      6.537775
# std      5017.0295         NaN      1.106918      0.500008      3.438776
# min         1.0000         NaN      1.000000      0.000000      1.000000
# 25%      4345.5000         NaN      2.000000      0.000000      4.000000
# 50%      8690.0000         NaN      3.000000      1.000000      7.000000
# 75%     13034.5000         NaN      3.000000      1.000000     10.000000
# max     17379.0000         NaN      4.000000      1.000000     12.000000
#
#                   hr       holiday       weekday    workingday    weathersit  \
# ...

# %% [markdown]
# Mencari rata-rata jam berapa peminjaman sepeda dilakukan pada hari libur

# %%
hour_df.groupby(by="holiday").hr.mean()
# Out:
# holiday
# 0    11.546182
# 1    11.566000
# Name: hr, dtype: float64

# %% [markdown]
# **Insight:**
# - untuk mencari tau musim apa yang memiliki jumlah peminjaman sepeda terbanyak, perlu mengelompokan data berdasarkan season lalu dicari nilai maks nya
# - untuk mencari tau waktu rata-rata peminjaman sepeda di hari libur, perlu mengelompokan data berdasarkan holiday lalu mencari nilai meannya

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Pada musim apa jumlah penyewaan sepeda paling banyak dilakukan dalam beberapa bulan terakhir?

# %% [markdown]
# Season yang memiliki jumlah peminjaman sepeda terbanyak

# %%
mappings = {
    1: "musim semi",
    2: "musim panas",
    3: "musim gugur",
    4: "musim dingin"
}

max_season_df = day_df.groupby("season").cnt.max().sort_values(ascending=False).reset_index()
max_season_df["season"] = max_season_df["season"].map(mappings)
max_season_df.head()
# Out:
#          season   cnt
# 0   musim gugur  8714
# 1  musim dingin  8555
# 2   musim panas  8362
# 3    musim semi  7836

# %% [markdown]
# Membuat Bar Chart dari data season yang memiliki jumlah cnt maksimal(terbanyak)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(24, 6))

colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="cnt", y="season", data=max_season_df, palette=colors, ax=ax)
ax.set_ylabel(None)
ax.set_xlabel(None)
ax.set_title("Highest Bicycle Rental Demand Season", loc="center", fontsize=15)
ax.tick_params(axis ='y', labelsize=12)

plt.show()
# Out:
# <ipython-input-17-fcd6f6c02f56>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="cnt", y="season", data=max_season_df, palette=colors, ax=ax)

# %% [markdown]
# ### Pertanyaan 2: Bagaimana perbandingan rata-rata jam peminjaman sepeda yang dilakukan di hari libur dan bukan hari libur?

# %%
mean_hr_by_holiday = hour_df.groupby('holiday')['hr'].mean()

sns.barplot(x=mean_hr_by_holiday.index, y=mean_hr_by_holiday.values)

plt.xlabel('Hari Libur (0: Bukan Libur, 1: Libur)')
plt.ylabel('Rata-rata Jam')
plt.title('Perbandingan Rata-rata Jam pada Hari Libur dan Bukan Libur')

plt.show()

# %% [markdown]
# **Insight:**
# - untuk mencari data terbaik atau terbanyak yang ingin di highlight dapat menggunakan barplot dengan pilihan warna berbeda pada data yang ingin di highlight
# - untuk mencari data perbandingan rata-rata, bisa menggunakan barplot tapi tidak ada warna yang di highlight

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Musim yang memiliki jumlah penyewaan sepeda paling banyak dilakukan dalam beberapa bulan terakhir adalah musim gugur
# - Perbandingan rata-rata jam peminjaman sepeda yang dilakukan di hari libur dan bukan hari libur adalah sama-sama dilakukan pada jam 11an siang
